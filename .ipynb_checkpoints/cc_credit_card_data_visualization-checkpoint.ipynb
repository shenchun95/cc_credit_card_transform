# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet("transformed_cc_credit_card\cc_credit_card_transformed.parquet")

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### [1] Distribution for transaction amount

# %%
# Print the minimum and maximum transaction amounts
print(f"Minimun transaction amount: {df['amt'].min()}\nMaximum transaction amount: {df['amt'].max()}")
# Out:
# Minimun transaction amount: 1.0
# Maximum transaction amount: 28948.9

# %%
# print the frequency distribution of transaction amounts

bins = [0,20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720, 740, 760, 780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220, 1240, 1260, 1280, 1300, 1320, 1340, 1360, 1380, 1400, 1420, 1440, 1460, 1480, 1500, 1520, 1540, 1560, 1580, 1600, 1620, 1640, 1660, 1680, 1700, 1720, 1740, 1760, 1780, 1800, 1820, 1840, 1860, 1880, 1900, 1920, 1940, 1960, 1980, 2000, float('inf')] 
frequency_table = pd.cut(df['amt'], bins=bins).value_counts().sort_index()  
print("Frequency Distribution of Amount:")
print(frequency_table)
# Out:
# Frequency Distribution of Amount:
# amt
# (0.0, 20.0]         424429
# (20.0, 40.0]        157956
# (40.0, 60.0]        186632
# (60.0, 80.0]        181879
# (80.0, 100.0]       110886
# (100.0, 120.0]       66520
# (120.0, 140.0]       45224
# (140.0, 160.0]       27396
# (160.0, 180.0]       17336
# (180.0, 200.0]       16493
# (200.0, 220.0]       13199
# (220.0, 240.0]        7854
# (240.0, 260.0]        4414
# (260.0, 280.0]        3269
# (280.0, 300.0]        2890
# (300.0, 320.0]        2529
# (320.0, 340.0]        2021
# (340.0, 360.0]        1545
# (360.0, 380.0]        1320
# (380.0, 400.0]        1185
# (400.0, 420.0]        1070
# (420.0, 440.0]        1061
# (440.0, 460.0]        1233
# (460.0, 480.0]        1367
# (480.0, 500.0]        1336
# (500.0, 520.0]        1268
# (520.0, 540.0]        1088
# (540.0, 560.0]         890
# (560.0, 580.0]         702
# (580.0, 600.0]         610
# (600.0, 620.0]         472
# (620.0, 640.0]         397
# (640.0, 660.0]         363
# (660.0, 680.0]         374
# (680.0, 700.0]         339
# (700.0, 720.0]         346
# (720.0, 740.0]         383
# (740.0, 760.0]         367
# (760.0, 780.0]         416
# (780.0, 800.0]         398
# (800.0, 820.0]         335
# (820.0, 840.0]         336
# (840.0, 860.0]         339
# (860.0, 880.0]         344
# (880.0, 900.0]         325
# (900.0, 920.0]         347
# (920.0, 940.0]         340
# (940.0, 960.0]         310
# (960.0, 980.0]         314
# (980.0, 1000.0]        292
# (1000.0, 1020.0]       277
# (1020.0, 1040.0]       233
# (1040.0, 1060.0]       229
# (1060.0, 1080.0]       205
# (1080.0, 1100.0]       189
# (1100.0, 1120.0]       155
# (1120.0, 1140.0]       154
# (1140.0, 1160.0]       133
# (1160.0, 1180.0]       102
# (1180.0, 1200.0]        93
# (1200.0, 1220.0]       108
# (1220.0, 1240.0]        78
# (1240.0, 1260.0]        70
# (1260.0, 1280.0]        53
# (1280.0, 1300.0]        76
# (1300.0, 1320.0]        59
# (1320.0, 1340.0]        62
# (1340.0, 1360.0]        43
# (1360.0, 1380.0]        53
# (1380.0, 1400.0]        60
# (1400.0, 1420.0]        58
# (1420.0, 1440.0]        35
# (1440.0, 1460.0]        31
# (1460.0, 1480.0]        51
# (1480.0, 1500.0]        33
# (1500.0, 1520.0]        48
# (1520.0, 1540.0]        35
# (1540.0, 1560.0]        30
# (1560.0, 1580.0]        35
# (1580.0, 1600.0]        27
# (1600.0, 1620.0]        36
# (1620.0, 1640.0]        30
# (1640.0, 1660.0]        18
# (1660.0, 1680.0]        31
# (1680.0, 1700.0]        21
# (1700.0, 1720.0]        14
# (1720.0, 1740.0]        18
# (1740.0, 1760.0]        23
# (1760.0, 1780.0]        16
# (1780.0, 1800.0]        21
# (1800.0, 1820.0]        21
# (1820.0, 1840.0]        21
# (1840.0, 1860.0]        24
# (1860.0, 1880.0]        14
# (1880.0, 1900.0]        15
# (1900.0, 1920.0]        14
# (1920.0, 1940.0]        11
# (1940.0, 1960.0]        17
# (1960.0, 1980.0]        13
# (1980.0, 2000.0]        12
# (2000.0, inf]          731
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['amt'], bins=bins, color='skyblue')
plt.title('Histogram of Transaction Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# c:\Users\chia_\OneDrive\Desktop\DE_inter\paynet\venv\Lib\site-packages\seaborn\distributions.py:474: RuntimeWarning: invalid value encountered in subtract
#   edges = res[orient].to_numpy() - widths / 2

# %% [markdown]
# ### Conclusion [1]
# <p>
# Most of the transaction happen below majority of transactions fall below 20 ~36.9% <br>
# strong right-skewed distribution where most transactions are small <br>
# <br>
# ~92% of the transaction is below 100 <br>
# Only 720 transaction from the dataset is >2000 <br>
# </p>

# %%
# ------------------------------------------------------ Section 2------------------------------------------------------------------

# %% [markdown]
# ### [2] transaction count/amount over time

# %%
txn_df = df.copy()

# %%
txn_df.head(5)
# Out:
#   Unnamed: 0    trans_date_trans_time  \
# 0     162992  2019-03-27 14:58:13.000
# 1     212746  2019-04-18 20:55:39.000
# 2     163146  2019-03-27 17:02:27.000
# 3     212752  2019-04-18 20:59:06.000
# 4     163392  2019-03-27 19:58:58.000
#
#                                                          cc_num  \
# 0  Mkpx4n8KHhhaZSf7htKJDgjx5V261mHr1Gr1eTtgbN5Xm+fl5j8oA3cqrAc=
# 1      RyOtgM3SMgWnAacPK4UUKIt1GTtGN0ME2KO+5qPjP7x+YNYHHNkbbRU=
# 2      uVB2QAYiRq7BgPC+pxns0NWzd+CetyiCEjBfpk9m0A7/26XoqT9Wvbba
# 3  T4I0YKYTwpgSB8Kh/Wv4NRCbZ2EyzEf2ZL7OI0dHknx9VOiooHbQeXalxQQ=
# 4  qq/LxLlhPXxpG9Nf4QieGT/pKcOtbaRVyhkSV+uVzkMUQrkZXq3Kn7bb6z0=
#
#                         merchant     amt  \
# 0           fraud_Lind-Buckridge  131.71
# 1            fraud_Wilkinson Ltd  108.68
# 2  fraud_Schaefer, Fay and Hilll   51.92
# 3               fraud_Grimes LLC   11.71
# 4               fraud_Nienow PLC   21.44
#
#                                                   first  \
# 0      cSlmBFtNUIIwci6e1txKbyCp2cd/MkN13a7iOBvFqEp5MPGU
# 1      AwgrJYO3V5nUcnNQ0AbSMUkUz4DazYEUC2nAa1FJ1O/u9pRT
# 2  LRzQ2GUAiHDJnzUbdxv+cs6m0W4LKNfrf+cBgvWRCC2SzI0Ykg==
# 3      KywqreWHWGysvJsBt32ffhUED24TJ15socjzfdv9UBXcG4U=
# 4      o4PYmupU1AsmcBgx+eRaJ7iBm8Un7hthJBhXzZGyJDRhc5Q=
#
#                                                last  \
# 0  H5RDp3dHGGaRpA93Hi+2mb9zu+qfckzf9cKP+9AglG4vZg==
# 1  Lcx+2OqoLTPF8MojiF5wEQ3VaxnbuIRZejl/a2hKbYzg3A==
# 2      4hqKie7DvSFXbnW8djp5o+u2V7qRk34Cm9FLFyxv+C6D
# 3      J4HpCb7vfOIuTEeHEmpm03gxIL2rK0+5ETOGxC6hQzNg
# 4  91l5aXc+vSrnVFOQ8Ac2pHictmV5poDuXnEe7OeiqtsFKIo=
#
#                                                                          street  \
# 0  9oXHXrUl1Jmnh25E8PKZV2yEWaCJL1SA3YCQ9Oqu/rOd8cbyiqphu1STNCIJG6lP0duaSPCEOA==
# 1      cdZs7576fHwR1XZTV+j1OTqmgMa11WYDj3LPvG3BzI2G4XI9A/8B8nGR3PiyzudjOLEwCrr7
# 2              zWLybp1CPxyiuVKNf+iSOlrSdZWJ24usLvXdtOt7DlWzj4doVzZkDzRqKFDXaQ==
# 3  HeD5zdG8Lcasd7hVhp9RR2OI3HSpwh24SJZMx9qmvnFewrJrhiF/uvKbvPxGGEPl/v8JmEsaIw==
# 4                  +Cml3xQaYfZNi37nWhSHO+4Gb4VkJJExNyQeLB8bYTRsiKgdkQjsfmOB6Bf2
#
#             city state    zip      lat      long  city_pop  \
# 0      Hurricane    WV  25526  38.4257  -81.9943     21902
# 1       Rosewood    OH  43070  40.2158  -83.9579       133
# 2        Central    IN  47110  38.0970  -86.1723       350
# 3  Drakes Branch    VA  23937  36.9688  -78.5615      1970
# 4       Manville    WY  82227  42.7300 -104.7024       241
#
#                         job  \
# 0                       Sub
# 1        Professor Emeritus
# 2                Counsellor
# 3           Energy engineer
# 4  Educational psychologist
#
#                                                     dob  \
# 0  /BtX9LbvQIFGs9R4o8iDE1TCJ2kaoHQEknsMb+Gc12i3KP4m+ko=
# 1  HDVoU+P9dL0FNKbyWsNOXFL9dvgCzfBjGOnzkJSt8GalMfcLqiE=
# 2  UzLNTBi8PABTuFVYT/Raj86tIFel2mvVQhpLkCJoT7Sx2Ug8JQY=
# 3  nGjh7vnDlOhEGLsrMZplOmRd0z+BnSkJqdhcuzJvHjpUWQbnjzs=
# 4  vWQe7DfrsDmrq1hU862kqaj9kAraFZZgsc+szzrLjYVFwNjL1HQ=
#
#                           trans_num  merch_lat  merch_long  is_fraud  \
# 0  9d10998aac3d3103a14eb79d9f0fced5  38.445424  -81.292151         0
# 1  997a78a55cc54c63ae39363c62162a53  40.390694  -83.591434         0
# 2  2ae3152edabad7535bfde77ace64479e  38.765765  -86.943872         0
# 3  09b840f44eee2a1358da6435fbdd0181  36.201029  -78.395291         0
# 4  48054f8a85ffdff03d901db3b5983d37  43.045387 -104.668606         0
#
#   merch_zipcode   merch_last_update_time           merch_eff_time  age  \
# 0         25030  1970-01-16 17:44:20.000  2012-03-27 22:58:13.000   45
# 1         43358  1970-01-16 18:16:22.000  2012-04-19 04:55:39.000   71
# 2         47562  1970-01-16 17:44:27.000  2012-03-28 01:02:27.000   70
# 3         27544  1970-01-16 18:16:22.000  2012-04-19 04:59:06.000   40
# 4         82224  1970-01-16 17:44:38.000  2012-03-28 03:58:58.000   45
#
#      cc_bic       category gender
# 0  ACEEUS31  entertainment      F
# 1  ACEEUS31  entertainment      F
# 2  ACEEUS31  entertainment      F
# 3  ACEEUS31  entertainment      F
# 4  ACEEUS31  entertainment      F

# %%
txn_df['trans_date_trans_time'] = pd.to_datetime(txn_df['trans_date_trans_time'])

# %%
# group by resample 'ME' -> date month end 
# reason using ME instead of MS is because i wish to standardize the number of transaction [foramt] in each month as of end of month 
monthly_amount = txn_df.set_index('trans_date_trans_time')['amt'].resample('ME').sum()
monthly_count = txn_df.set_index('trans_date_trans_time')['amt'].resample('ME').count()

# %%
fig, ax1 = plt.subplots(figsize=(14, 6))

plt.title('Monthly Total Transaction Amount and Transaction Count')

ax1.plot(monthly_amount.index.strftime('%Y%m'), monthly_amount.values / 1000000, marker='o', linestyle='-', color='b')
ax1.set_xlabel('Month')
ax1.set_ylabel('Total Amount (in Million)', color='b')
ax1.tick_params(axis='y', labelcolor='b')

ax2 = ax1.twinx()
ax2.bar(monthly_count.index.strftime('%Y%m'), monthly_count.values, color='g', alpha=.3, width=0.5,label='Transaction Count')
ax2.set_ylabel('Transaction Count', color='g')
ax2.tick_params(axis='y', labelcolor='g')

plt.tight_layout()

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(14, 6))
plt.title('Average Transaction Amount per Transaction')

ax1.plot(monthly_amount.index.strftime('%Y%m'), monthly_amount / monthly_count , marker='o', linestyle='-', color='r')
ax1.set_xlabel('Month')
ax1.set_ylabel('Amount', color='b')
ax1.tick_params(axis='y', labelcolor='b')
plt.tight_layout()

plt.show()

# %%
print(f'lower limit: {min(monthly_amount / monthly_count)}\nupper limit: {max(monthly_amount / monthly_count)}\nrange: {min(monthly_amount / monthly_count)}')
# Out:
# lower limit: 69.22341888071064
# upper limit: 72.28697368948782
# range: 69.22341888071064

# %%
(monthly_amount / monthly_count).mean()
# Out:
# np.float64(70.43291312799958)

# %%
monthly_amount.corr(monthly_count)
# Out:
# np.float64(0.9995962727109472)

# %% [markdown]
# ### Conclusion [2]
#
# <p>
#
# Most of the transaction happen on December 2019 <br>
# Post-December 2019, there\'s a sharp decline in both amount and count, possibly due to a seasonal or external event (e.g., holidays, economic changes). <br>
# the average transaction amount/transaction per month is between 69.22 and 72.28 with the highest of 72.28 on February 2019
#
# the data denode a strong positive correlation (0.99995) between the number of transaction with the total transaction amount<br>
# <br>
#
# <br>
# </p>

# %%
demographic_df = df.copy()

# %%
demographic_df.head(5)
# Out:
#   Unnamed: 0    trans_date_trans_time  \
# 0     162992  2019-03-27 14:58:13.000
# 1     212746  2019-04-18 20:55:39.000
# 2     163146  2019-03-27 17:02:27.000
# 3     212752  2019-04-18 20:59:06.000
# 4     163392  2019-03-27 19:58:58.000
#
#                                                          cc_num  \
# 0  Mkpx4n8KHhhaZSf7htKJDgjx5V261mHr1Gr1eTtgbN5Xm+fl5j8oA3cqrAc=
# 1      RyOtgM3SMgWnAacPK4UUKIt1GTtGN0ME2KO+5qPjP7x+YNYHHNkbbRU=
# 2      uVB2QAYiRq7BgPC+pxns0NWzd+CetyiCEjBfpk9m0A7/26XoqT9Wvbba
# 3  T4I0YKYTwpgSB8Kh/Wv4NRCbZ2EyzEf2ZL7OI0dHknx9VOiooHbQeXalxQQ=
# 4  qq/LxLlhPXxpG9Nf4QieGT/pKcOtbaRVyhkSV+uVzkMUQrkZXq3Kn7bb6z0=
#
#                         merchant     amt  \
# 0           fraud_Lind-Buckridge  131.71
# 1            fraud_Wilkinson Ltd  108.68
# 2  fraud_Schaefer, Fay and Hilll   51.92
# 3               fraud_Grimes LLC   11.71
# 4               fraud_Nienow PLC   21.44
#
#                                                   first  \
# 0      cSlmBFtNUIIwci6e1txKbyCp2cd/MkN13a7iOBvFqEp5MPGU
# 1      AwgrJYO3V5nUcnNQ0AbSMUkUz4DazYEUC2nAa1FJ1O/u9pRT
# 2  LRzQ2GUAiHDJnzUbdxv+cs6m0W4LKNfrf+cBgvWRCC2SzI0Ykg==
# 3      KywqreWHWGysvJsBt32ffhUED24TJ15socjzfdv9UBXcG4U=
# 4      o4PYmupU1AsmcBgx+eRaJ7iBm8Un7hthJBhXzZGyJDRhc5Q=
#
#                                                last  \
# 0  H5RDp3dHGGaRpA93Hi+2mb9zu+qfckzf9cKP+9AglG4vZg==
# 1  Lcx+2OqoLTPF8MojiF5wEQ3VaxnbuIRZejl/a2hKbYzg3A==
# 2      4hqKie7DvSFXbnW8djp5o+u2V7qRk34Cm9FLFyxv+C6D
# 3      J4HpCb7vfOIuTEeHEmpm03gxIL2rK0+5ETOGxC6hQzNg
# 4  91l5aXc+vSrnVFOQ8Ac2pHictmV5poDuXnEe7OeiqtsFKIo=
#
#                                                                          street  \
# 0  9oXHXrUl1Jmnh25E8PKZV2yEWaCJL1SA3YCQ9Oqu/rOd8cbyiqphu1STNCIJG6lP0duaSPCEOA==
# 1      cdZs7576fHwR1XZTV+j1OTqmgMa11WYDj3LPvG3BzI2G4XI9A/8B8nGR3PiyzudjOLEwCrr7
# 2              zWLybp1CPxyiuVKNf+iSOlrSdZWJ24usLvXdtOt7DlWzj4doVzZkDzRqKFDXaQ==
# 3  HeD5zdG8Lcasd7hVhp9RR2OI3HSpwh24SJZMx9qmvnFewrJrhiF/uvKbvPxGGEPl/v8JmEsaIw==
# 4                  +Cml3xQaYfZNi37nWhSHO+4Gb4VkJJExNyQeLB8bYTRsiKgdkQjsfmOB6Bf2
#
#             city state    zip      lat      long  city_pop  \
# 0      Hurricane    WV  25526  38.4257  -81.9943     21902
# 1       Rosewood    OH  43070  40.2158  -83.9579       133
# 2        Central    IN  47110  38.0970  -86.1723       350
# 3  Drakes Branch    VA  23937  36.9688  -78.5615      1970
# 4       Manville    WY  82227  42.7300 -104.7024       241
#
#                         job  \
# 0                       Sub
# 1        Professor Emeritus
# 2                Counsellor
# 3           Energy engineer
# 4  Educational psychologist
#
#                                                     dob  \
# 0  /BtX9LbvQIFGs9R4o8iDE1TCJ2kaoHQEknsMb+Gc12i3KP4m+ko=
# 1  HDVoU+P9dL0FNKbyWsNOXFL9dvgCzfBjGOnzkJSt8GalMfcLqiE=
# 2  UzLNTBi8PABTuFVYT/Raj86tIFel2mvVQhpLkCJoT7Sx2Ug8JQY=
# 3  nGjh7vnDlOhEGLsrMZplOmRd0z+BnSkJqdhcuzJvHjpUWQbnjzs=
# 4  vWQe7DfrsDmrq1hU862kqaj9kAraFZZgsc+szzrLjYVFwNjL1HQ=
#
#                           trans_num  merch_lat  merch_long  is_fraud  \
# 0  9d10998aac3d3103a14eb79d9f0fced5  38.445424  -81.292151         0
# 1  997a78a55cc54c63ae39363c62162a53  40.390694  -83.591434         0
# 2  2ae3152edabad7535bfde77ace64479e  38.765765  -86.943872         0
# 3  09b840f44eee2a1358da6435fbdd0181  36.201029  -78.395291         0
# 4  48054f8a85ffdff03d901db3b5983d37  43.045387 -104.668606         0
#
#   merch_zipcode   merch_last_update_time           merch_eff_time  age  \
# 0         25030  1970-01-16 17:44:20.000  2012-03-27 22:58:13.000   45
# 1         43358  1970-01-16 18:16:22.000  2012-04-19 04:55:39.000   71
# 2         47562  1970-01-16 17:44:27.000  2012-03-28 01:02:27.000   70
# 3         27544  1970-01-16 18:16:22.000  2012-04-19 04:59:06.000   40
# 4         82224  1970-01-16 17:44:38.000  2012-03-28 03:58:58.000   45
#
#      cc_bic       category gender
# 0  ACEEUS31  entertainment      F
# 1  ACEEUS31  entertainment      F
# 2  ACEEUS31  entertainment      F
# 3  ACEEUS31  entertainment      F
# 4  ACEEUS31  entertainment      F

# %%
# create surrogate key for each person with first and last name
demographic_df['person_id'] = demographic_df.groupby(['first','last']).ngroup()

# %%
demographic_df.head(5)
# Out:
#   Unnamed: 0    trans_date_trans_time  \
# 0     162992  2019-03-27 14:58:13.000
# 1     212746  2019-04-18 20:55:39.000
# 2     163146  2019-03-27 17:02:27.000
# 3     212752  2019-04-18 20:59:06.000
# 4     163392  2019-03-27 19:58:58.000
#
#                                                          cc_num  \
# 0  Mkpx4n8KHhhaZSf7htKJDgjx5V261mHr1Gr1eTtgbN5Xm+fl5j8oA3cqrAc=
# 1      RyOtgM3SMgWnAacPK4UUKIt1GTtGN0ME2KO+5qPjP7x+YNYHHNkbbRU=
# 2      uVB2QAYiRq7BgPC+pxns0NWzd+CetyiCEjBfpk9m0A7/26XoqT9Wvbba
# 3  T4I0YKYTwpgSB8Kh/Wv4NRCbZ2EyzEf2ZL7OI0dHknx9VOiooHbQeXalxQQ=
# 4  qq/LxLlhPXxpG9Nf4QieGT/pKcOtbaRVyhkSV+uVzkMUQrkZXq3Kn7bb6z0=
#
#                         merchant     amt  \
# 0           fraud_Lind-Buckridge  131.71
# 1            fraud_Wilkinson Ltd  108.68
# 2  fraud_Schaefer, Fay and Hilll   51.92
# 3               fraud_Grimes LLC   11.71
# 4               fraud_Nienow PLC   21.44
#
#                                                   first  \
# 0      cSlmBFtNUIIwci6e1txKbyCp2cd/MkN13a7iOBvFqEp5MPGU
# 1      AwgrJYO3V5nUcnNQ0AbSMUkUz4DazYEUC2nAa1FJ1O/u9pRT
# 2  LRzQ2GUAiHDJnzUbdxv+cs6m0W4LKNfrf+cBgvWRCC2SzI0Ykg==
# 3      KywqreWHWGysvJsBt32ffhUED24TJ15socjzfdv9UBXcG4U=
# 4      o4PYmupU1AsmcBgx+eRaJ7iBm8Un7hthJBhXzZGyJDRhc5Q=
#
#                                                last  \
# 0  H5RDp3dHGGaRpA93Hi+2mb9zu+qfckzf9cKP+9AglG4vZg==
# 1  Lcx+2OqoLTPF8MojiF5wEQ3VaxnbuIRZejl/a2hKbYzg3A==
# 2      4hqKie7DvSFXbnW8djp5o+u2V7qRk34Cm9FLFyxv+C6D
# 3      J4HpCb7vfOIuTEeHEmpm03gxIL2rK0+5ETOGxC6hQzNg
# 4  91l5aXc+vSrnVFOQ8Ac2pHictmV5poDuXnEe7OeiqtsFKIo=
#
#                                                                          street  \
# 0  9oXHXrUl1Jmnh25E8PKZV2yEWaCJL1SA3YCQ9Oqu/rOd8cbyiqphu1STNCIJG6lP0duaSPCEOA==
# 1      cdZs7576fHwR1XZTV+j1OTqmgMa11WYDj3LPvG3BzI2G4XI9A/8B8nGR3PiyzudjOLEwCrr7
# 2              zWLybp1CPxyiuVKNf+iSOlrSdZWJ24usLvXdtOt7DlWzj4doVzZkDzRqKFDXaQ==
# 3  HeD5zdG8Lcasd7hVhp9RR2OI3HSpwh24SJZMx9qmvnFewrJrhiF/uvKbvPxGGEPl/v8JmEsaIw==
# 4                  +Cml3xQaYfZNi37nWhSHO+4Gb4VkJJExNyQeLB8bYTRsiKgdkQjsfmOB6Bf2
#
#             city state    zip      lat      long  city_pop  \
# 0      Hurricane    WV  25526  38.4257  -81.9943     21902
# 1       Rosewood    OH  43070  40.2158  -83.9579       133
# 2        Central    IN  47110  38.0970  -86.1723       350
# 3  Drakes Branch    VA  23937  36.9688  -78.5615      1970
# 4       Manville    WY  82227  42.7300 -104.7024       241
#
#                         job  \
# 0                       Sub
# 1        Professor Emeritus
# 2                Counsellor
# 3           Energy engineer
# 4  Educational psychologist
#
#                                                     dob  \
# 0  /BtX9LbvQIFGs9R4o8iDE1TCJ2kaoHQEknsMb+Gc12i3KP4m+ko=
# 1  HDVoU+P9dL0FNKbyWsNOXFL9dvgCzfBjGOnzkJSt8GalMfcLqiE=
# 2  UzLNTBi8PABTuFVYT/Raj86tIFel2mvVQhpLkCJoT7Sx2Ug8JQY=
# 3  nGjh7vnDlOhEGLsrMZplOmRd0z+BnSkJqdhcuzJvHjpUWQbnjzs=
# 4  vWQe7DfrsDmrq1hU862kqaj9kAraFZZgsc+szzrLjYVFwNjL1HQ=
#
#                           trans_num  merch_lat  merch_long  is_fraud  \
# 0  9d10998aac3d3103a14eb79d9f0fced5  38.445424  -81.292151         0
# 1  997a78a55cc54c63ae39363c62162a53  40.390694  -83.591434         0
# 2  2ae3152edabad7535bfde77ace64479e  38.765765  -86.943872         0
# 3  09b840f44eee2a1358da6435fbdd0181  36.201029  -78.395291         0
# 4  48054f8a85ffdff03d901db3b5983d37  43.045387 -104.668606         0
#
#   merch_zipcode   merch_last_update_time           merch_eff_time  age  \
# 0         25030  1970-01-16 17:44:20.000  2012-03-27 22:58:13.000   45
# 1         43358  1970-01-16 18:16:22.000  2012-04-19 04:55:39.000   71
# 2         47562  1970-01-16 17:44:27.000  2012-03-28 01:02:27.000   70
# 3         27544  1970-01-16 18:16:22.000  2012-04-19 04:59:06.000   40
# 4         82224  1970-01-16 17:44:38.000  2012-03-28 03:58:58.000   45
#
#      cc_bic       category gender  person_id
# 0  ACEEUS31  entertainment      F     819596
# 1  ACEEUS31  entertainment      F     261634
# 2  ACEEUS31  entertainment      F     474883
# 3  ACEEUS31  entertainment      F     465090
# 4  ACEEUS31  entertainment      F    1055428

# %%
# extract unique person_id
demographic_var_df = demographic_df[['person_id','state','gender','age']].drop_duplicates()

# %%
demographic_var_df.head(5)
# Out:
#    person_id state gender  age
# 0     819596    WV      F   45
# 1     261634    OH      F   71
# 2     474883    IN      F   70
# 3     465090    VA      F   40
# 4    1055428    WY      F   45

# %%
demographic_df.head(5)
# Out:
#   Unnamed: 0    trans_date_trans_time  \
# 0     162992  2019-03-27 14:58:13.000
# 1     212746  2019-04-18 20:55:39.000
# 2     163146  2019-03-27 17:02:27.000
# 3     212752  2019-04-18 20:59:06.000
# 4     163392  2019-03-27 19:58:58.000
#
#                                                          cc_num  \
# 0  Mkpx4n8KHhhaZSf7htKJDgjx5V261mHr1Gr1eTtgbN5Xm+fl5j8oA3cqrAc=
# 1      RyOtgM3SMgWnAacPK4UUKIt1GTtGN0ME2KO+5qPjP7x+YNYHHNkbbRU=
# 2      uVB2QAYiRq7BgPC+pxns0NWzd+CetyiCEjBfpk9m0A7/26XoqT9Wvbba
# 3  T4I0YKYTwpgSB8Kh/Wv4NRCbZ2EyzEf2ZL7OI0dHknx9VOiooHbQeXalxQQ=
# 4  qq/LxLlhPXxpG9Nf4QieGT/pKcOtbaRVyhkSV+uVzkMUQrkZXq3Kn7bb6z0=
#
#                         merchant     amt  \
# 0           fraud_Lind-Buckridge  131.71
# 1            fraud_Wilkinson Ltd  108.68
# 2  fraud_Schaefer, Fay and Hilll   51.92
# 3               fraud_Grimes LLC   11.71
# 4               fraud_Nienow PLC   21.44
#
#                                                   first  \
# 0      cSlmBFtNUIIwci6e1txKbyCp2cd/MkN13a7iOBvFqEp5MPGU
# 1      AwgrJYO3V5nUcnNQ0AbSMUkUz4DazYEUC2nAa1FJ1O/u9pRT
# 2  LRzQ2GUAiHDJnzUbdxv+cs6m0W4LKNfrf+cBgvWRCC2SzI0Ykg==
# 3      KywqreWHWGysvJsBt32ffhUED24TJ15socjzfdv9UBXcG4U=
# 4      o4PYmupU1AsmcBgx+eRaJ7iBm8Un7hthJBhXzZGyJDRhc5Q=
#
#                                                last  \
# 0  H5RDp3dHGGaRpA93Hi+2mb9zu+qfckzf9cKP+9AglG4vZg==
# 1  Lcx+2OqoLTPF8MojiF5wEQ3VaxnbuIRZejl/a2hKbYzg3A==
# 2      4hqKie7DvSFXbnW8djp5o+u2V7qRk34Cm9FLFyxv+C6D
# 3      J4HpCb7vfOIuTEeHEmpm03gxIL2rK0+5ETOGxC6hQzNg
# 4  91l5aXc+vSrnVFOQ8Ac2pHictmV5poDuXnEe7OeiqtsFKIo=
#
#                                                                          street  \
# 0  9oXHXrUl1Jmnh25E8PKZV2yEWaCJL1SA3YCQ9Oqu/rOd8cbyiqphu1STNCIJG6lP0duaSPCEOA==
# 1      cdZs7576fHwR1XZTV+j1OTqmgMa11WYDj3LPvG3BzI2G4XI9A/8B8nGR3PiyzudjOLEwCrr7
# 2              zWLybp1CPxyiuVKNf+iSOlrSdZWJ24usLvXdtOt7DlWzj4doVzZkDzRqKFDXaQ==
# 3  HeD5zdG8Lcasd7hVhp9RR2OI3HSpwh24SJZMx9qmvnFewrJrhiF/uvKbvPxGGEPl/v8JmEsaIw==
# 4                  +Cml3xQaYfZNi37nWhSHO+4Gb4VkJJExNyQeLB8bYTRsiKgdkQjsfmOB6Bf2
#
#             city state    zip      lat      long  city_pop  \
# 0      Hurricane    WV  25526  38.4257  -81.9943     21902
# 1       Rosewood    OH  43070  40.2158  -83.9579       133
# 2        Central    IN  47110  38.0970  -86.1723       350
# 3  Drakes Branch    VA  23937  36.9688  -78.5615      1970
# 4       Manville    WY  82227  42.7300 -104.7024       241
#
#                         job  \
# 0                       Sub
# 1        Professor Emeritus
# 2                Counsellor
# 3           Energy engineer
# 4  Educational psychologist
#
#                                                     dob  \
# 0  /BtX9LbvQIFGs9R4o8iDE1TCJ2kaoHQEknsMb+Gc12i3KP4m+ko=
# 1  HDVoU+P9dL0FNKbyWsNOXFL9dvgCzfBjGOnzkJSt8GalMfcLqiE=
# 2  UzLNTBi8PABTuFVYT/Raj86tIFel2mvVQhpLkCJoT7Sx2Ug8JQY=
# 3  nGjh7vnDlOhEGLsrMZplOmRd0z+BnSkJqdhcuzJvHjpUWQbnjzs=
# 4  vWQe7DfrsDmrq1hU862kqaj9kAraFZZgsc+szzrLjYVFwNjL1HQ=
#
#                           trans_num  merch_lat  merch_long  is_fraud  \
# 0  9d10998aac3d3103a14eb79d9f0fced5  38.445424  -81.292151         0
# 1  997a78a55cc54c63ae39363c62162a53  40.390694  -83.591434         0
# 2  2ae3152edabad7535bfde77ace64479e  38.765765  -86.943872         0
# 3  09b840f44eee2a1358da6435fbdd0181  36.201029  -78.395291         0
# 4  48054f8a85ffdff03d901db3b5983d37  43.045387 -104.668606         0
#
#   merch_zipcode   merch_last_update_time           merch_eff_time  age  \
# 0         25030  1970-01-16 17:44:20.000  2012-03-27 22:58:13.000   45
# 1         43358  1970-01-16 18:16:22.000  2012-04-19 04:55:39.000   71
# 2         47562  1970-01-16 17:44:27.000  2012-03-28 01:02:27.000   70
# 3         27544  1970-01-16 18:16:22.000  2012-04-19 04:59:06.000   40
# 4         82224  1970-01-16 17:44:38.000  2012-03-28 03:58:58.000   45
#
#      cc_bic       category gender  person_id
# 0  ACEEUS31  entertainment      F     819596
# 1  ACEEUS31  entertainment      F     261634
# 2  ACEEUS31  entertainment      F     474883
# 3  ACEEUS31  entertainment      F     465090
# 4  ACEEUS31  entertainment      F    1055428

# %%
plt.figure(figsize=(14, 6))
plt.hist(demographic_var_df['age'], bins=10, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Number of People')
plt.title('Users Age distribution')
plt.show()

# %%
bins = np.linspace(demographic_var_df['age'].min(), demographic_var_df['age'].max(), 20)  

male_age_freq, _ = np.histogram(demographic_var_df[demographic_var_df['gender'] == 'M']['age'], bins=bins)
female_age_freq, _ = np.histogram(demographic_var_df[demographic_var_df['gender'] == 'F']['age'], bins=bins)

bin_centers = (bins[:-1] + bins[1:]) / 2

plt.figure(figsize=(14, 6))
plt.plot(bin_centers, male_age_freq, label='Male')
plt.plot(bin_centers, female_age_freq, label='Female')

plt.xlabel('Age')
plt.ylabel('Number of Users')
plt.title('Age Distribution by Gender')
plt.legend()
plt.grid(True, alpha=0.5)
plt.show()

# %%
#  get the state table at US_state.csv
state_df = pd.read_csv('US_state.csv')
state_df.head(5)
# Out:
#    State Name Abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
demographic_var_df.head(3)
# Out:
#    person_id state gender  age
# 0     819596    WV      F   45
# 1     261634    OH      F   71
# 2     474883    IN      F   70

# %%
merged_state_df = pd.merge(demographic_var_df, state_df, left_on='state', right_on='Abbreviation', how='left')

# %%
age_gender_spending = demographic_df.groupby(['age','gender']).size()
# Out:
# C:\Users\chia_\AppData\Local\Temp\ipykernel_5304\159080244.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_gender_spending = demographic_df.groupby(['age','gender']).size()

# %%
age_gender_spending = age_gender_spending.reset_index()
age_gender_spending.columns = ['age','gender','frequency']

# %%
age_gender_spending.dtypes
# Out:
# age             int32
# gender       category
# frequency       int64
# dtype: object

# %%
#  reference for bin : https://realpython.com/np-linspace-numpy/
bins = np.linspace(10, 100, 10) # Example: 5 bins
labels = [f'{int(bins[i])}-{int(bins[i+1])}' for i in range(len(bins) - 1)]

# Create a new column for the age group
age_gender_spending['age_group'] = pd.cut(age_gender_spending['age'], bins=bins, labels=labels, right=False)

# Group by age group and gender, and sum the frequency
grouped_spending = age_gender_spending.groupby(['age_group', 'gender'])['frequency'].sum().reset_index()

male_age_freq = grouped_spending[grouped_spending['gender'] == 'M']['frequency']
female_age_freq = grouped_spending[grouped_spending['gender'] == 'F']['frequency']
total_freq = (male_age_freq.reset_index() + female_age_freq.reset_index())['frequency']

plt.figure(figsize=(14, 6))
plt.bar(grouped_spending[grouped_spending['gender'] == 'M']['age_group'],total_freq, label='Total', alpha=0.4,color='g')

plt.plot(grouped_spending[grouped_spending['gender'] == 'M']['age_group'],male_age_freq, label='Male', color = 'blue')
plt.plot(grouped_spending[grouped_spending['gender'] == 'F']['age_group'], female_age_freq, label='Female', color = 'red')

plt.xlabel('Age')
plt.ylabel('transaction count')
plt.title('transaction count by Gender & age group')
plt.legend()
plt.grid(True, alpha=0.2)
plt.show()
# Out:
# C:\Users\chia_\AppData\Local\Temp\ipykernel_5304\1463805328.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_spending = age_gender_spending.groupby(['age_group', 'gender'])['frequency'].sum().reset_index()

# %% [markdown]
# ### Conclusion [3]
#
# <p>
#
# Most of the credit card transaction from the dataset is done by age group 30 to 60 and generally more transaction was done by Female than Male<br>
# This was mainly due to the fact that most of the female population is in this age group and also due to the fact that there are more females than males in the dataset <br>
# </p>

# %%
df.head(4)
# Out:
#   Unnamed: 0    trans_date_trans_time  \
# 0     162992  2019-03-27 14:58:13.000
# 1     212746  2019-04-18 20:55:39.000
# 2     163146  2019-03-27 17:02:27.000
# 3     212752  2019-04-18 20:59:06.000
#
#                                                          cc_num  \
# 0  Mkpx4n8KHhhaZSf7htKJDgjx5V261mHr1Gr1eTtgbN5Xm+fl5j8oA3cqrAc=
# 1      RyOtgM3SMgWnAacPK4UUKIt1GTtGN0ME2KO+5qPjP7x+YNYHHNkbbRU=
# 2      uVB2QAYiRq7BgPC+pxns0NWzd+CetyiCEjBfpk9m0A7/26XoqT9Wvbba
# 3  T4I0YKYTwpgSB8Kh/Wv4NRCbZ2EyzEf2ZL7OI0dHknx9VOiooHbQeXalxQQ=
#
#                         merchant     amt  \
# 0           fraud_Lind-Buckridge  131.71
# 1            fraud_Wilkinson Ltd  108.68
# 2  fraud_Schaefer, Fay and Hilll   51.92
# 3               fraud_Grimes LLC   11.71
#
#                                                   first  \
# 0      cSlmBFtNUIIwci6e1txKbyCp2cd/MkN13a7iOBvFqEp5MPGU
# 1      AwgrJYO3V5nUcnNQ0AbSMUkUz4DazYEUC2nAa1FJ1O/u9pRT
# 2  LRzQ2GUAiHDJnzUbdxv+cs6m0W4LKNfrf+cBgvWRCC2SzI0Ykg==
# 3      KywqreWHWGysvJsBt32ffhUED24TJ15socjzfdv9UBXcG4U=
#
#                                                last  \
# 0  H5RDp3dHGGaRpA93Hi+2mb9zu+qfckzf9cKP+9AglG4vZg==
# 1  Lcx+2OqoLTPF8MojiF5wEQ3VaxnbuIRZejl/a2hKbYzg3A==
# 2      4hqKie7DvSFXbnW8djp5o+u2V7qRk34Cm9FLFyxv+C6D
# 3      J4HpCb7vfOIuTEeHEmpm03gxIL2rK0+5ETOGxC6hQzNg
#
#                                                                          street  \
# 0  9oXHXrUl1Jmnh25E8PKZV2yEWaCJL1SA3YCQ9Oqu/rOd8cbyiqphu1STNCIJG6lP0duaSPCEOA==
# 1      cdZs7576fHwR1XZTV+j1OTqmgMa11WYDj3LPvG3BzI2G4XI9A/8B8nGR3PiyzudjOLEwCrr7
# 2              zWLybp1CPxyiuVKNf+iSOlrSdZWJ24usLvXdtOt7DlWzj4doVzZkDzRqKFDXaQ==
# 3  HeD5zdG8Lcasd7hVhp9RR2OI3HSpwh24SJZMx9qmvnFewrJrhiF/uvKbvPxGGEPl/v8JmEsaIw==
#
#             city state    zip      lat     long  city_pop                 job  \
# 0      Hurricane    WV  25526  38.4257 -81.9943     21902                 Sub
# 1       Rosewood    OH  43070  40.2158 -83.9579       133  Professor Emeritus
# 2        Central    IN  47110  38.0970 -86.1723       350          Counsellor
# 3  Drakes Branch    VA  23937  36.9688 -78.5615      1970     Energy engineer
#
#                                                     dob  \
# 0  /BtX9LbvQIFGs9R4o8iDE1TCJ2kaoHQEknsMb+Gc12i3KP4m+ko=
# 1  HDVoU+P9dL0FNKbyWsNOXFL9dvgCzfBjGOnzkJSt8GalMfcLqiE=
# 2  UzLNTBi8PABTuFVYT/Raj86tIFel2mvVQhpLkCJoT7Sx2Ug8JQY=
# 3  nGjh7vnDlOhEGLsrMZplOmRd0z+BnSkJqdhcuzJvHjpUWQbnjzs=
#
#                           trans_num  merch_lat  merch_long  is_fraud  \
# 0  9d10998aac3d3103a14eb79d9f0fced5  38.445424  -81.292151         0
# 1  997a78a55cc54c63ae39363c62162a53  40.390694  -83.591434         0
# 2  2ae3152edabad7535bfde77ace64479e  38.765765  -86.943872         0
# 3  09b840f44eee2a1358da6435fbdd0181  36.201029  -78.395291         0
#
#   merch_zipcode   merch_last_update_time           merch_eff_time  age  \
# 0         25030  1970-01-16 17:44:20.000  2012-03-27 22:58:13.000   45
# 1         43358  1970-01-16 18:16:22.000  2012-04-19 04:55:39.000   71
# 2         47562  1970-01-16 17:44:27.000  2012-03-28 01:02:27.000   70
# 3         27544  1970-01-16 18:16:22.000  2012-04-19 04:59:06.000   40
#
#      cc_bic       category gender
# 0  ACEEUS31  entertainment      F
# 1  ACEEUS31  entertainment      F
# 2  ACEEUS31  entertainment      F
# 3  ACEEUS31  entertainment      F
